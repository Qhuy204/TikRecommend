# %%
# !python main.py --mode train --epochs 30
# Out:
# ...
# 🚀 SASRec + PhoBERT Training Pipeline
# ...
#
# 📂 Loading data...
# 📂 Loading data from ../data/raw/tiki_dataset.jsonl...
# Reading JSONL: 143140it [01:10, 2031.06it/s]
# 🔧 Building ID mappings...
# ✅ Loaded 123,016 items, 114,498 users
#    Skipped: 17,686 errors/redirect, 2,438 duplicates
#    Total interactions: 646,498
#
# 📊 Creating dataloaders...
# 📊 Split: 114498 train, 114498 val, 114498 test users
#
# 🔧 Creating SASRec model...
#    Items: 123,016
#    Users: 114,498
#    Parameters: 7,940,160
#
# 🚀 Starting training for 30 epochs
#    Device: cuda
#    Batch size: 128
#    Training samples: 303,004
# ...
# Evaluating: 100%|█████████████████████████████| 895/895 [00:11<00:00, 80.78it/s]
#
# 📊 Epoch 1/30
#    Train Loss: 0.1949
#    Val HR@10: 0.0380
#    Val NDCG@10: 0.0178
#    ✅ New best model saved!
# ...
# Evaluating: 100%|█████████████████████████████| 895/895 [00:10<00:00, 82.41it/s]
#
# 📊 Epoch 2/30
#    Train Loss: 0.0969
#    Val HR@10: 0.0300
#    Val NDCG@10: 0.0186
# ...

# %%
from demo import DemoRecommender
demo = DemoRecommender()
# Out:
# ...
# 🚀 Initializing Demo Recommender...
# ...
#
# 📂 Loading data...
# 📂 Loading data from ../data/raw/tiki_dataset.jsonl...
# Reading JSONL: 143140it [01:21, 1753.95it/s]
# 🔧 Building ID mappings...
# ✅ Loaded 123,016 items, 114,498 users
#    Skipped: 17,686 errors/redirect, 2,438 duplicates
#    Total interactions: 646,498
#
# 🔧 Loading model...
# ✅ Loaded recommender from checkpoints/best_model.pt
#
# ✅ Ready to use!
#    Items: 123,016
#    Users: 114,498
# ...

# %%
demo.recommend_user() # Random user
# Out:
# 👤 Recommendations for User 347541
# ----------------------------------------
# 📝 History (10 items):
#    • Thức Ăn Cho Chó Royal Canin Poodle Puppy... (5⭐)
#    • Tông Đơ Cắt Tỉa Lông Chuyên Nghiệp Cho Chó Mè... (5⭐)
#    • Sách Lên Đỉnh Núi Mở Tiệm Bánh Mì - Triết lí ... (5⭐)
#
# 🎯 Top 10 Recommendations:
#    1. Sách Cây Cam Ngọt Của Tôi...
#       📂 Sách tiếng Việt
#       💰 86,400 VND
#       ⭐ Score: 9.3368
#
#    2. Sách Nhà Giả Kim (Tái Bản 2020)...
#       📂 Sách tiếng Việt
#       💰 60,830 VND
#       ⭐ Score: 8.3839
#
#    3. Sách Hoàng Tử Bé (Tái Bản 2019)...
#       📂 Sách tiếng Việt
#       💰 60,000 VND
#       ⭐ Score: 8.3543
#
#    4. Tinh dầu nguyên chất Bạc Hà 24Care/ Sả chanh/ Quế/ Oải ...
#       📂 Sản phẩm thiên nhiên & Khác
#       💰 345,000 VND
#       ⭐ Score: 8.2937
#
#    5. Sách Người Đua Diều (Tái Bản 2018)...
#       📂 Sách tiếng Việt
#       💰 103,200 VND
#       ⭐ Score: 8.1399
#
#    6. Sách Điều Kỳ Diệu Của Tiệm Tạp Hóa NAMIYA (Tái Bản)...
# ...

# %%
demo.similar_items(41382) # Items tương tự
# Out:
# 🔍 Similar to Item 41382
# ----------------------------------------
# 📦 Query: Ống Mực Cao Cấp Lamy T10
#    📂 Văn phòng phẩm | 💰 135,000 VND
#
# 🎯 Top 10 Similar:
#    1. Combo 4 Miếng Dán Dùng Cho Máy Massage Xung Điện PEAFLO...
#       📂 Máy Massage & Thiết bị chăm sóc sức khỏe
#       💰 35,000 VND
#       ⭐ Score: 0.6121
#
#    2. Bộ hai ổ khóa dùng chung 1 chìa chính hãng Abus 75/ 50m...
#       📂 Dụng cụ & Thiết bị tiện ích
#       💰 642,000 VND
#       ⭐ Score: 0.5682
#
#    3. Dép nữ da bò thật BIGGBEN cao cấp DNQN37...
#       📂 Dép - Guốc nữ
#       💰 319,000 VND
#       ⭐ Score: 0.5593
#
#    4. Dép lê cho bé trai 3 - 12 tuổi hình xe tăng nhựa dẻo mề...
#       📂 Thời trang bé trai
#       💰 95,000 VND
#       ⭐ Score: 0.5583
#
#    5. Combo 2 Tinh Dầu Xông Phòng Kobi: Tinh Dầu Sả Chanh (50...
#       📂 Sản phẩm thiên nhiên & Khác
#       💰 219,000 VND
#       ⭐ Score: 0.5400
#
#    6. Khăn trải bàn PAULEE –WB-601L (135 x 180 cm)...
#       📂 Đồ dùng phòng ăn
# ...

# %%
demo.similar_items()
# Out:
# 🔍 Similar to Item 204212208
# ----------------------------------------
# 📦 Query: [Elemental chính hãng - Thương hiệu Mỹ] Cốc giữ nhiệt Elemental Summit 470ml, giữ nhiệt vượt trội, an toàn sức khỏe, inox 304, giá siêu hot
#    📂 Đồ dùng phòng ăn | 💰 643,080 VND
#
# 🎯 Top 10 Similar:
#    1. Cáp USB Type C to USB 3.0 Ugreen 20882 dài 1m chính hãn...
#       📂 Phụ kiện máy tính và Laptop
#       💰 81,000 VND
#       ⭐ Score: 0.9284
#
#    2. Combo 5 Đôi Tất , Vớ Nam / Nữ Cổ Ngắn Trơn Siêu Mềm Mại...
#       📂 Phụ kiện thời trang nữ
#       💰 42,000 VND
#       ⭐ Score: 0.9256
#
#    3. Trà Chùm Ngây (Hộp 50 Túi Lọc X 2g) - Nguyên Thái Trang...
#       📂 Đồ uống
#       💰 73,999 VND
#       ⭐ Score: 0.9254
#
#    4. Lồng cơm giữ nhiệt, hộp cơm văn phòng Mitomo LCH-7086, ...
#       📂 Dụng cụ nhà bếp
#       💰 1,152,000 VND
#       ⭐ Score: 0.9240
#
#    5. Nước mắm cá cơm Nhất Hảo 30N 520ml...
#       📂 Gia Vị và Chế Biến
#       💰 85,000 VND
#       ⭐ Score: 0.9228
#
# ...

# %%
demo.recommend_sequence([200948942, 273128915, 275867801])
# Out:
# 🛒 Session-based Recommendation
# ----------------------------------------
# 📝 Input sequence (3 items):
#    • COMBO VIÊN THẢ LẨU 5 TRONG 1 _ STEAM BOAT 5IN...
#    • Cây Lăn Mát Xa Mũi Nâng Cơ Vùng Mũi Bằng Nhựa...
#    • Bộ Chổi Xẻng Mini Hình Thú Dễ Thương - Chổi Q...
#
# 🎯 Recommended next:
#    1. Bàn Là, Bàn Ủi Hơi Nước cầm tay SOKANY AJ2205- Công suấ...
#       📂 Thiết bị gia đình
#       💰 523,000 VND
#       ⭐ Score: 8.6537
#
#    2. Truyện - Doraemon Truyện Ngắn - Chọn Lẻ Tập 25 Tới 45 -...
#       📂 Sách tiếng Việt
#       💰 26,000 VND
#       ⭐ Score: 8.3156
#
#    3. Máy xay thịt, máy xay tói ớt đa năng công suất mạnh mẽ ...
#       📂 Đồ dùng nhà bếp
#       💰 559,000 VND
#       ⭐ Score: 8.2845
#
#    4. Máy sấy tóc 2 chiều nóng lạnh SOKANY SK-14020 công suất...
#       📂 Thiết bị gia đình
#       💰 823,000 VND
#       ⭐ Score: 8.2229
#
#    5. Giày thể thao nam, giày chạy bộ nam phong cách mới – GN...
#       📂 Chạy bộ và đi bộ
#       💰 290,000 VND
# ...

# %%
demo.get_sample_users(5)
# Out:
# [1494741, 7278090, 11601444, 7943757, 27466761]

# %%
demo.get_sample_items(5)
# Out:
# [200948942, 128568924, 273128915, 277175972, 275867801]
