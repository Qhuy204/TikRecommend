# %%
# !python preprocessing.py
# Out:
# ✅ Cache exists: ../data/processed/lightgcn_processed.pkl
# 📂 Loading from ../data/processed/lightgcn_processed.pkl...
#    Users: 109,567 | Items: 19,855
#
# ...
# ✅ Done!
# ...

# %%
# !python train.py --epochs 50 --layers 3
# Out:
# 📂 Loading data...
# 📂 Loading from ../data/processed/lightgcn_processed.pkl...
#    Users: 109,567 | Items: 19,855
# 📊 Dataset: Train 485,087 | Val 60,635 | Test 60,637
#
# 🔧 Creating LightGCN model...
# /home/qhuy/recommendation-system/LightGCN/models.py:19: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   indices = torch.LongTensor([coo.row, coo.col])
#    Users: 109,567
#    Items: 19,855
#    GCN Layers: 3
#    Parameters: 8,283,008
#
# ...
# 🚀 LightGCN Training
# ...
#    Epochs: 50
#    Device: cuda
#    GCN Layers: 3
#    Samples: 485,087
# ...
# Evaluating: 100%|█████████████████████████████| 237/237 [00:15<00:00, 15.37it/s]
#
# 📊 Epoch 1/50
#    Loss: 0.4822 | BPR: 0.4822
#    HR@10: 0.0543 | NDCG@10: 0.0307
#    ✅ New best!
# ...

# %%
# !python evaluate.py
# Out:
# 📂 Loading data...
# 📂 Loading from ../data/processed/lightgcn_processed.pkl...
#    Users: 109,567 | Items: 19,855
# 📊 Dataset: Train 485,087 | Val 60,635 | Test 60,637
# 🔧 Loading model...
# /home/qhuy/recommendation-system/LightGCN/models.py:19: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   indices = torch.LongTensor([coo.row, coo.col])
#    Loaded: epoch 49, HR@10=0.1331
# Evaluating: 100%|█████████████████████████████| 237/237 [00:08<00:00, 29.34it/s]
#
# ...
# 📊 LightGCN Results (test)
# ...
#
# 📈 Hit Rate:
#    HR@10: 0.1350
#    HR@20: 0.1876
#    HR@5: 0.0928
#
# 📈 NDCG:
#    NDCG@10: 0.0785
#    NDCG@20: 0.0918
#    NDCG@5: 0.0650
#
# 📈 MRR: 0.0650
#
# 💾 Saved: checkpoints/eval_test.json

# %%
# !python demo.py
# Out:
# ...
# 🚀 LightGCN Demo
# ...
#
# 📂 Loading data...
# 📂 Loading from ../data/processed/lightgcn_processed.pkl...
#    Users: 109,567 | Items: 19,855
#
# 🔧 Loading model...
# /home/qhuy/recommendation-system/LightGCN/models.py:19: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   indices = torch.LongTensor([coo.row, coo.col])
#    Loaded: epoch 49, HR@10=0.1331
#
# ✅ Ready! Users: 109,567 | Items: 19,855
# ...
#
#
# ...
# 📌 USAGE
# ...
#
# demo.recommend_user(12345)   # User recommendations
# demo.similar_items(277725)   # Similar items
# demo.random_demo(top_k=3)    # Random demo
#
#
# ...
# 🎲 RANDOM DEMO
# ...
#
# 👤 Recommendations for User 796179
# ----------------------------------------
# 📝 History (7 items)
#
# 🎯 Top 3 Recommendations:
#    1. Dụng cụ băm rau củ quả Lock&Lock Quick Chopper...
# ...
