# %%
# !python preprocessing.py
# Out:
# ...
# 📂 PhoBERT Content-Based Preprocessing
# ...
#    Source: ../data/clean/tiki_dataset_clean.jsonl
#
# 📖 Reading JSONL...
# Loading: 125501it [01:24, 1480.75it/s]
#    Total lines: 125,501
#    Valid products: 123,016
#    Skipped errors: 47
#    Skipped duplicates: 2,438
#
# 🔧 Building ID mappings (ALL items)...
#    Total items: 123,016
#
# 🔧 Building user data...
#    Total users: 104,796
#    Total positive interactions: 581,357
#
# 🤖 Loading PhoBERT...
#    Model: vinai/phobert-base
#    Device: cuda
#
# 🔧 Encoding 123,016 items...
# Encoding: 100%|█████████████████████████████| 3845/3845 [09:55<00:00,  6.46it/s]
#    Embeddings shape: torch.Size([123016, 768])
#    Normalized: L2 norm = 1.0
#
# 💾 Saving to ../data/processed/phobert_processed.pkl...
# 💾 Saving embeddings to ../data/processed/phobert_embeddings.pt...
#    Data size: 88.6 MB
#    Embeddings size: 180.2 MB
#
# ...
# ✅ Done!
# ...

# %%
# !python demo.py
# Out:
# ...
# 🚀 PhoBERT Content-Based Demo
# ...
#
# 📂 Loading data...
# 📂 Loading from ../data/processed/phobert_processed.pkl...
# 📂 Loading embeddings from ../data/processed/phobert_embeddings.pt...
#    Items: 123,016
#    Users: 104,796
#    Embeddings shape: torch.Size([123016, 768])
#
# 🔧 Initializing recommender...
#
# ✅ Ready!
#    Items: 123,016
#    Users: 104,796
#    Embedding dim: 768
# ...
#
#
# ...
# 📌 USAGE
# ...
#
# demo.recommend_user(12345)       # User recommendations
# demo.recommend_user()            # Random user
#
# demo.similar_items(277725874)    # Similar items
# demo.similar_items()             # Random item
#
# demo.recommend_sequence([1,2,3]) # From item list
#
# demo.get_sample_users(5)         # Sample user IDs
# demo.get_sample_items(5)         # Sample item IDs
#
#
# ...
# 🎲 RANDOM DEMO
# ...
#
# 👤 Recommendations for User 726310
# ----------------------------------------
# 📝 Liked items (4):
#    • Dung dịch dưỡng ẩm tối ưu Hada Labo Advanced Nouri...
# ...

# %%
from demo import DemoRecommender

demo = DemoRecommender()
# Out:
# ...
# 🚀 PhoBERT Content-Based Demo
# ...
#
# 📂 Loading data...
# 📂 Loading from ../data/processed/phobert_processed.pkl...
# 📂 Loading embeddings from ../data/processed/phobert_embeddings.pt...
#    Items: 123,016
#    Users: 104,796
#    Embeddings shape: torch.Size([123016, 768])
#
# 🔧 Initializing recommender...
#
# ✅ Ready!
#    Items: 123,016
#    Users: 104,796
#    Embedding dim: 768
# ...

# %%
demo.show_sample_users(10)  # Hiện 10 random users với số liked items
demo.show_sample_items(10)  # Hiện 10 random items với name, category
# Out:
# 👥 Random 10 Users:
# ------------------------------------------------------------
#     1. ID: 32452        | Liked items: 3
#     2. ID: 8345861      | Liked items: 4
#     3. ID: 11930346     | Liked items: 5
#     4. ID: 29644407     | Liked items: 5
#     5. ID: 12539522     | Liked items: 3
#     6. ID: 11052092     | Liked items: 4
#     7. ID: 12637815     | Liked items: 3
#     8. ID: 11145744     | Liked items: 24
#     9. ID: 6332189      | Liked items: 7
#    10. ID: 12472697     | Liked items: 3
# ------------------------------------------------------------
# 💡 Usage: demo.recommend_user(32452)
#
# 📦 Random 10 Items:
# --------------------------------------------------------------------------------
#     1. ID: 195192657    | Quần đùi thể thao nam Fasvin S22514 HN v | Gym và Boxing
#     2. ID: 192546445    | Nhuộm Tóc Phủ Bạc Magic Lavox            | Chăm sóc tóc và da đ
#     3. ID: 95269415     | Tã Dán Siêu Cao Cấp Huggies Platinum Nat | Tã, Bỉm
# ...

# %%
demo.recommend_user(11052092)
# Out:
# 👤 Recommendations for User 11052092
# ----------------------------------------
# 📝 Liked items (4):
#    • Xi nước đánh giày da đồ da Hando 80ml màu Đen...
#    • Thẻ nhớ Camera Ezviz 64Gb Class 10 Tốc Độ Cao Cho ...
#    • Đe n năng lượng mặt trời chống lóa Vạn Năng Solar ...
#    • Tai nghe không dây Xiaomi Redmi Buds 4 Lite Hàng c...
#
# 🎯 Top 10 Recommendations:
#    1. Máy Hút Bụi Dùng Pin Makita DCL182Z Hàng chính hãng...
#       📂 Thiết bị gia đình
#       💰 1,640,000 VND
#       ⭐ Score: 0.8479
#
#    2. Thẻ nhớ EZVIZ 64Gb chuyên dùng cho camera chuẩn Class 1...
#       📂 Phụ Kiện Máy Ảnh, Máy Quay
#       💰 175,000 VND
#       ⭐ Score: 0.8421
#
#    3. Bộ Sạc Pin AA AAA DP UK22 Doublepow Kiểu Sạc USB Sạc 2 ...
#       📂 Dụng cụ & Thiết bị tiện ích
#       💰 581,000 VND
#       ⭐ Score: 0.8383
#
#    4. Miếng dán PPF màn hình dẻo CHỐNG NHÌN TRỘM dành cho Sam...
#       📂 Phụ Kiện Điện Thoại và Máy Tính Bảng
#       💰 119,999 VND
#       ⭐ Score: 0.8382
#
# ...

# %%
demo.similar_items(276425643)        # Find similar items
# Out:
# 🔍 Similar to Item 276425643
# ----------------------------------------
# 📦 Query: Đèn bàn ăn thả trần bếp trang trí phòng khách quán SuperVilighting phong cách hiện đại trắng đen bảo hành 24 tháng
#    📂 Đèn & thiết bị chiếu sáng | 💰 284,960 VND
#
# 🎯 Top 10 Similar:
#    1. Đèn treo thả trần nhà phòng khách bàn ăn quán phong các...
#       📂 Đèn & thiết bị chiếu sáng
#       💰 369,200 VND
#       ⭐ Score: 0.9248
#
#    2. Đèn treo trần nhà trang trí phòng khách phòng ngủ bàn ă...
#       📂 Đèn & thiết bị chiếu sáng
#       💰 984,880 VND
#       ⭐ Score: 0.9061
#
#    3. Đèn trang trí quán SuperVilighting treo phòng khách bàn...
#       📂 Đèn & thiết bị chiếu sáng
#       💰 733,200 VND
#       ⭐ Score: 0.9048
#
#    4. Đèn treo phòng thả trần phòng khách trang trí bàn ăn qu...
#       📂 Đèn & thiết bị chiếu sáng
#       💰 234,000 VND
#       ⭐ Score: 0.8793
#
#    5. Đèn thả bàn ăn hiện đại trang trí trần nhà phòng khách ...
#       📂 Đèn & thiết bị chiếu sáng
#       💰 629,200 VND
# ...

# %%
demo.recommend_sequence([1, 2, 3])   # Cold-start

# %%
demo.random_demo()
# Out:
# ...
# 🎲 RANDOM DEMO
# ...
#
# 👤 Recommendations for User 17808948
# ----------------------------------------
# 📝 Liked items (3):
#    • Khẩu Trang Y Tế TDCare 4 Lớp Hộp 50 Cái...
#    • Cây treo quần áo 3 chân 8 nhánh treo bằng gỗ cao s...
#    • Bình Đun Siêu Tốc 2 lớp Lock Lock EJK738WHT 1 7 Lí...
#
# 🎯 Top 5 Recommendations:
#    1. Kính Mắt Nam Nữ Chống Ánh Sáng Xanh Từ Máy Tinh Tv Điện...
#       📂 Mắt kính
#       💰 129,000 VND
#       ⭐ Score: 0.8230
#
#    2. MUA 1 LỐC TẶNG 2 CUỘN GVS 4 LỚP PRESTIGE NGẪU NHIÊN Giấ...
#       📂 Giấy vệ sinh và giấy ăn
#       💰 260,000 VND
#       ⭐ Score: 0.8207
#
#    3. Combo Bao Khăn Giấy Ướt Super WUNA 20x25cm 100 Cái Bao...
#       📂 Chăm sóc cá nhân
#       💰 55,000 VND
#       ⭐ Score: 0.8179
#
#    4. Thùng 30 gói Khăn Giấy Rút Gấu Trúc 3 Lớp MyLan Siêu Da...
#       📂 Giấy vệ sinh và giấy ăn
#       💰 198,000 VND
#       ⭐ Score: 0.8137
#
#    5. Bộ 3 hộp đựng cơm 2 hộp chữ nhật 370ml và 1 tròn 400ml ...
#       📂 Dụng cụ nhà bếp
# ...

# %%
# !python evaluate.py --sample-users 5000 --test-ratio 0.2
# Out:
# ...
# 📊 PhoBERT Content-Based Evaluation
# ...
#
# 📂 Loading data...
# 📂 Loading from ../data/processed/phobert_processed.pkl...
# 📂 Loading embeddings from ../data/processed/phobert_embeddings.pt...
#    Items: 123,016
#    Users: 104,796
#    Embeddings shape: torch.Size([123016, 768])
#
# 🔧 Creating recommender...
#
# 📊 Creating train/test split...
#    Test users: 104,796
#    Test items: 126,203 (held-out 20% per user)
#
# 🔧 Computing metrics...
#    ⚡ Sampling 5,000 users for faster evaluation
# Evaluating: 100%|███████████████████████████| 5000/5000 [02:00<00:00, 41.66it/s]
#
# 🔧 Computing category precision...
# Category Precision: 100%|███████████████████| 1000/1000 [00:23<00:00, 42.18it/s]
#
# ...
# 📊 PhoBERT Results
# ...
#
# 📈 Hit Rate:
#    HR@10: 0.0346
#    HR@20: 0.0458
#    HR@5: 0.0271
#
# 📈 NDCG:
#    NDCG@10: 0.0215
#    NDCG@20: 0.0243
#    NDCG@5: 0.0191
#
# 📈 MRR: 0.0182
#
# 📈 Category Precision@10: 0.5563
#
# 💾 Saved: eval_results.json

# %%
# !python evaluate.py --test-ratio 0.2
# Out:
# ...
# 📊 PhoBERT Content-Based Evaluation
# ...
#
# 📂 Loading data...
# 📂 Loading from ../data/processed/phobert_processed.pkl...
# 📂 Loading embeddings from ../data/processed/phobert_embeddings.pt...
#    Items: 123,016
#    Users: 104,796
#    Embeddings shape: torch.Size([123016, 768])
#
# 🔧 Creating recommender...
#
# 📊 Creating train/test split...
#    Test users: 104,796
#    Test items: 126,203 (held-out 20% per user)
#
# 🔧 Computing metrics...
# Evaluating: 100%|███████████████████████| 104796/104796 [43:26<00:00, 40.21it/s]
#
# 🔧 Computing category precision...
# Category Precision: 100%|███████████████████| 1000/1000 [00:26<00:00, 37.98it/s]
#
# ...
# 📊 PhoBERT Results
# ...
#
# 📈 Hit Rate:
#    HR@10: 0.0388
#    HR@20: 0.0504
#    HR@5: 0.0287
#
# 📈 NDCG:
#    NDCG@10: 0.0235
#    NDCG@20: 0.0264
#    NDCG@5: 0.0202
#
# 📈 MRR: 0.0195
#
# 📈 Category Precision@10: 0.5790
#
# 💾 Saved: eval_results.json
